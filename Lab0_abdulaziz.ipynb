# %% [markdown]
# <a href="https://colab.research.google.com/github/madaminvv/NewUUOOp_week10/blob/master/Lab0_abdulaziz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 0 — Colab and Python
#
# **Fundamentals of Data Science · New Uzbekistan University**
#
# Your name:
#
# Date:
#
# ---
#
# Work through this notebook in order. **Type every line yourself** — do not copy and paste, and do not just read it. Typing is how the syntax gets into your hands.
#
# Cells marked **YOUR TURN** are empty on purpose. Fill them in.
#
# Before you leave: **Runtime → Restart and run all**, then **File → Save a copy in Drive**.

# %% [markdown]
# ## 0:00–0:15 · Setup
#
# Run the cell below. If you see `hello` underneath it, Colab works.

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# **Do these three things now, before going on:**
#
# 1. **File → Save a copy in Drive.** Colab wipes temporary storage after about 90 minutes of inactivity. Anything not in Drive is gone, with no recovery.
# 2. Rename the copy to `Lab0_yourname`.
# 3. Find **Runtime → Restart and run all** in the menu. Do not click it yet. Just find it.

# %% [markdown]
# ## 0:15–0:35 · Task 1 — Values, variables, and types
#
# A variable is a name for a value. Read `=` as *becomes*, not as *equals*.

# %%
students = 1200
course_name = "Fundamentals of Data Science"

print(students)
print(course_name)
# Out:
# 1200
# Fundamentals of Data Science

# %% [markdown]
# **1.1 YOUR TURN.** Make a variable `my_name` holding your name, and print it.

# %%
my_name="Abdulazizbek"
print(my_name)
# Out:
# Abdulazizbek

# %% [markdown]
# **1.2** Run this. The two lines do different things. Predict each one *before* you run it.

# %%
print(14 + 1)
print("14" + "1")
# Out:
# 15
# 141

# %% [markdown]
# **1.3 YOUR TURN.** Run `type()` on a number and on text. Then write one sentence below saying why the difference matters when a student ID is stored as a number.
#
# *Your answer:*

# %%
print(type(14+1))
print(type("14"+"1"))
when he writes id there is a word and numbers so he writes word with str and number with int
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## 0:35–0:55 · Task 2 — Lists, and questions that return True or False

# %%
scores = [72, 65, 58, 91]

print(len(scores))
print(scores[0])
print(sum(scores) / len(scores))
# Out:
# 4
# 72
# 71.5

# %% [markdown]
# **2.1 YOUR TURN.** Print the *last* item of `scores` in two different ways.

# %%
print(scores[3])
print(scores[len(scores)-1])
# Out:
# 91
# 91

# %% [markdown]
# **2.2** Predict the answer out loud, then run it.

# %%
score = 72

print(score > 50)
print(score == 100)
print(score > 50 and score > 100)
# Out:
# True
# False
# False

# %% [markdown]
# **2.3 YOUR TURN.** Write an `if / elif / else` that prints `Distinction` for 70 and above, `Pass` for 50 to 69, and `Fail` below 50. Test it with 45, 50 and 72.
#
# Then answer: does a score of exactly 50 pass? Where in your code is that decided?
#
# *Your answer:*

# %%
score=50;
if score >=70:
  print("distinction")
elif score >=50:
    print("pass")
else:
  print("fail")
# Out:
# pass

# %% [markdown]
# ## 0:55–1:10 · Break

# %% [markdown]
# ## 1:10–1:25 · Task 3 — Functions
#
# **This one is assessed.** The Week 1 diagnostic asks you to write a function.

# %%
def average(numbers):
    return sum(numbers) / len(numbers)

print(average(scores))
# Out:
# 71.5

# %% [markdown]
# **3.1 YOUR TURN.** Write `largest(numbers)` that returns the biggest value in a list. Test it on `scores`.

# %%
def largest(scores):
  return max(scores)
print(largest(scores))
# Out:
# 91

# %% [markdown]
# **3.2** Run this, then explain what happened.
#
# *Your answer:*

# %%
def shows_average(numbers):
    print(sum(numbers) / len(numbers))

x = shows_average(scores)
print("x holds:", x)
# Out:
# 71.5
# x holds: None

# %% [markdown]
# ## 1:25–1:40 · Task 4 — Break it on purpose
#
# An error means Python stopped *before* doing something wrong. That is the good outcome.
#
# Read the **last line** of an error message first. It names the problem.

# %%
print(studnets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4945/2844826339.py in <cell line: 0>()
# ----> 1 print(studnets)
#
# NameError: name 'studnets' is not defined

# %% [markdown]
# **4.1 YOUR TURN.** Produce each of these errors on purpose, one per cell below. Write down the last line of each message.
#
# - `TypeError`
# - `IndentationError`
# - `IndexError`
# - `FileNotFoundError`

# %%
print("hello"+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4945/1684405547.py in <cell line: 0>()
# ----> 1 print("hello"+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
if True:
print("hi")
# Out:
#   File "/tmp/ipykernel_4945/3681110552.py", line 2
#     print("hi")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
numbers = [1,2,3]
print(numbers[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_4945/2678341036.py in <cell line: 0>()
#       1 numbers = [1,2,3]
# ----> 2 print(numbers[4])
#
# IndexError: list index out of range

# %%
open("fhgafhga")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4945/928474247.py in <cell line: 0>()
# ----> 1 open("fhgafhga")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fhgafhga'

# %% [markdown]
# ## 1:40–1:50 · Task 5 — Your first real table
#
# Now connect Drive and load actual data. This is the setup cell you will use in every lab for the rest of the course.

# %%
from google.colab import drive
drive.mount('/content/drive')

DATA = "/content/drive/MyDrive/fds/data/"      # change if your folder differs

import pandas as pd

students = pd.read_csv(DATA + "students.csv")
print(students.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (1200, 7)

# %% [markdown]
# You should see `(1200, 7)`. If you do not, look at the troubleshooting table in the lab sheet.

# %%
students.head()

# %% [markdown]
# **5.1 YOUR TURN.** Using `students`, print each of these on its own line:
#
# 1. how many students are in each `programme`
# 2. how many *distinct* values `student_id` has
# 3. the mean `entry_score`

# %%
print(students["programme"].value_counts())
print(students["studenbt"])

# %% [markdown]
# **5.2 YOUR TURN.** Load `enrolments.csv` into a variable called `enrolments` and print its shape.
#
# Then answer, in words, without running anything else: **is the number of rows in `enrolments` the number of students?** Why or why not?
#
# *Your answer:*

# %%
# your code here

# %% [markdown]
# ## 1:50–2:00 · Checkpoint and write-up
#
# **Checkpoint — you are done when all of these are true:**
#
# - [ ] `print("hello")` ran
# - [ ] you saved a copy to Drive and renamed it
# - [ ] `largest()` works and returns a value
# - [ ] you produced four different errors on purpose and wrote down the last line of each
# - [ ] `students.shape` printed `(1200, 7)`
# - [ ] **Runtime → Restart and run all** ran the whole notebook with no errors
#
# ---
#
# **Write-up (about 100 words).** Answer in the cell below:
#
# 1. Which error did you find hardest to understand, and what did the message turn out to mean?
# 2. `enrolments.csv` has more rows than `students.csv`. What do you think one row of it is?
#
# *Your write-up:*

# %% [markdown]
# ---
#
# **Before you submit**
#
# 1. **Runtime → Restart and run all.** Every cell must run top to bottom with no errors — except the four in Task 4, which are meant to fail.
# 2. **File → Save a copy in Drive.**
# 3. Submit the notebook in the LMS.
#
# If something did not work today, tell your instructor **before you leave**. It will not fix itself, and Lab 1 assumes it works.
